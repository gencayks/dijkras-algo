# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Plot
plt.figure(figsize=(10,6))
plt.plot(x, y, label='Sine Wave', color='cyan')
plt.title("RTX 4080 Rendering to Mac M4")
plt.grid(True)
plt.show()
